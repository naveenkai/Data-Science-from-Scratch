# %% [markdown]
# ## Types of Data

# %% [markdown]
# ### 1. Numerical data - quantitative data (measured) - height, weight
# ### 2. Categorical data - categories - gender, nationality, color
# ### 3. Time series data - data points collected at regular intervals of time - stock prices, wether data, traffic data
# ### 4. Text data - unstructured data - words, sentences, emails, social media posts, reviews
# ### 5. Image data - photos, MRI scans, satellite images
# ### 6. Audio data - music, speech and sound effects

# %% [markdown]
# ## Data formats

# %% [markdown]
# ### 1. CSV(Comma Separated Values)

# %%
import pandas as pd
data = pd.read_csv('tips.csv')
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ### 2. JSON (Java Script Object Notation)

# %%
import json
with open ('json data.json') as f:
    data1 = json.load(f)

# %%
data1
# Out:
# {'BaseInformation': [{'Code': 'Local',
#    'NamespacePrefix': 'report',
#    'NamespaceIdentifier': 'http://www.xbrlsite.com/report',
#    'SchemaLocation': 'report.xsd',
#    'DefaultLanguage': 'en',
#    'TaxonomyDescription': 'Report using MINI Financial Reporting Scheme'},
#   {'Code': 'Import',
#    'NamespacePrefix': 'mini',
#    'NamespaceIdentifier': 'http://xbrlsite.com/mini',
#    'SchemaLocation': 'http://www.xbrlsite.com/seattlemethod/golden/mini/base-taxonomy/mini.xsd',
#    'DefaultLanguage': 'en',
#    'TaxonomyDescription': 'MINI Financial Reporting Scheme'}],
#  'Terms': [{'Prefix': 'mini',
#    'ReportElementCategory': 'Concept',
#    'StandardLabel': 'Accounts Payable',
#    'ReportElementName': 'AccountsPayable',
#    'Datatype': 'Monetary',
#    'CalendarPeriodType': 'Instant',
#    'BalanceType': 'Credit'},
#   {'Prefix': 'mini',
#    'ReportElementCategory': 'Abstract',
#    'StandardLabel': 'Accounts Payable [Roll Forward]',
# ...

# %% [markdown]
# ### 3. XML (eXtensible Markup Language)

# %%
import xml.etree.ElementTree as ET
tree = ET.parse('BloodImage.xml')     ## parse - divide into grammatical parts
root = tree.getroot()

for child in root:
    print(child.tag, child.attrib)
# Out:
# folder {}
# filename {}
# path {}
# source {}
# size {}
# segmented {}
# object {}
# object {}
# object {}
# object {}
# object {}
# object {}
# object {}
# object {}
# object {}
# object {}
# object {}
# object {}
# object {}

# %% [markdown]
# ### 4. Excel

# %%
data4 = pd.read_excel("data_excel.xlsx")
data4
# Out:
#      Code NamespacePrefix             NamespaceIdentifier  \
# 0   Local          report  http://www.xbrlsite.com/report
# 1  Import            mini        http://xbrlsite.com/mini
#
#                                       SchemaLocation DefaultLanguage  \
# 0                                         report.xsd              en
# 1  http://www.xbrlsite.com/seattlemethod/golden/m...              en
#
#                             TaxonomyDescription
# 0  Report using MINI Financial Reporting Scheme
# 1               MINI Financial Reporting Scheme

# %% [markdown]
# ## Small project

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('world_population.csv')

# %%
data.head()
# Out:
#   CCA3           Name     2022     2020     2015     2010     2000     1990  \
# 0   CN          China  1425887  1424930  1393715  1348191  1264099  1153704
# 1   IN          India  1417173  1396387  1322867  1240614  1059634   870452
# 2   US  United States   338290   335942   324608   311183   282399   248084
# 3   ID      Indonesia   275501   271858   259092   244016   214072   182160
# 4   PK       Pakistan   235825   227197   210969   194454   154370   115414
#
#      1980    1970  Area (km²)  Density (per km²)  GrowthRate  \
# 0  982372  822534     9706961           146.8933        1.00
# 1  696828  557501     3287590           431.0675        1.01
# 2  223140  200328     9372610            36.0935        1.00
# 3  148177  115228     1904569           144.6529        1.01
# 4   80624   59291      881912           267.4018        1.02
#
#   World Population Percentage  Rank
# 0                      17.88%     1
# 1                      17.77%     2
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   CCA3                         233 non-null    object
#  1   Name                         234 non-null    object
#  2   2022                         234 non-null    int64
#  3   2020                         234 non-null    int64
#  4   2015                         234 non-null    int64
#  5   2010                         234 non-null    int64
#  6   2000                         234 non-null    int64
#  7   1990                         234 non-null    int64
#  8   1980                         234 non-null    int64
#  9   1970                         234 non-null    int64
#  10  Area (km²)                   234 non-null    int64
#  11  Density (per km²)            234 non-null    float64
#  12  GrowthRate                   234 non-null    float64
# ...

# %%
data['2022']
# Out:
# 0      1425887
# 1      1417173
# 2       338290
# 3       275501
# 4       235825
#         ...
# 229          4
# 230          4
# 231          2
# 232          2
# 233          1
# Name: 2022, Length: 234, dtype: int64

# %%
avg_population = data['2022'].mean()

# %%
print("Average population is ",avg_population)
# Out:
# Average population is  34074.41452991453

# %%
plt.bar(data['Name'].head(), data['2022'].head(), width = 1)
plt.xticks(rotation = 90)
plt.show()
